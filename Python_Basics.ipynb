# %%
v=5
v
# Out:
# 5

# %%
id(v)
# Out:
# 140720995738664

# %%
5=v
# Out:
#   Cell In[3], line 1
#     5=v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
v1=9
v1

# %%
v2=10
V2

# %%
a=11
A

# %%
v@=89

# %%
v*=90
v*

# %%
v_=10
v_

# %%
if=90

# %%
else-89

# %%
import keyword
keyword.kwlist

# %%
len(keyword.kwlist)

# %%
else=7

# %%
ELSE=90
ELSE

# %%
for=89
for

# %%
FOR=12
FOR

# %%
i=32
i

# %%
type(i)

# %%
german_cars(audi,bmw,skoda,volk)
asian(tata,mahin)

# %%
type()

# %%
1house(sand,brick,labour)
2house()

# %%
len(i)

# %%
f=110.1
f

# %%
type(f)

# %%
f2=1e0
f2

# %%
f3=1e2
f3

# %%
F5=1e5
F5

# %%
a=10
b=20
a+b

# %%
a-b

# %%
print(a+b)
print(a-b)
print(a*b)
print(a/b)

# %%
c=1+2j
type(c)

# %%
c.real

# %%
c.imag

# %%
c=5+10j
d=20+30j
print(c+d)
print(c-d)

# %%
def team():
    print("Helo")

# %%
c=2+3J
c

# %%
b=True
b

# %%
import keyword
keyword.kwlist

# %%
b1=False
b1

# %%
True+True

# %%
int(True)

# %%
True-False

# %%
False-True

# %%
True-True*False+1

# %%
s='anas'
s

# %%
p=20
q=20
r=20
print(p)
print(q)
print(r)

# %%
print(id(p))
print(id(q))
print(id(r))

# %%
p1,q1,r1=20,20,20
print(p1)
print(q1)
print(r1)

# %%
print(id(p1))
print(id(q1))
print(id(r1))

# %%
s='hello python'
s

# %%
len(s)

# %%
s[0] #forward indexing

# %%
s[-1] #backward indexing

# %%
s[:]

# %%
s[11]

# %%
s[0:5]

# %%
s[6:9]

# %%
s[-5:-1]

# %%
s[2:]

# %%
s[:6]

# %%
s[::-1]

# %%
s[2:10:2]

# %%
s[0:13:3]

# %%
s[0:10:5]

# %%
s1='nareshit'
s1

# %%
type(np.nan)

# %%
int(2.3)

# %%
int(2.5,3.4)

# %%
int(2)

# %%
int(True)

# %%
int(False)

# %%
int(True,False)

# %%
print(1+2j)

# %%
int('one')

# %%
print(float(2))
print(float(False))
print(float(2))
print(float(1+2j))
print(float(2))

# %%
print(float('two'))

# %%
float('2')

# %%
complex(10)

# %%
complex(10,20)

# %%
complex(10,20,30)

# %%
complex(2.6,3.7)

# %%
complex(3,2.6)

# %%
complex(False,False)

# %%
complex('1',23)

# %%
complex('1')

# %%
bool(1)

# %%
bool(2)

# %%
bool(0)

# %%
bool(1+2j)

# %%
bool(2)

# %%
bool()

# %%
str(2)

# %%
str(2.2)

# %%
str(True)

# %%
str('False')

# %%
a=8
type(8)

# %%
import sys
sys.version

# %%
l=[]
l

# %%
print(type(l))

# %%
l.append(10)
l

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l.append(30)
l

# %%
l[0]

# %%
l[0]=200
l

# %%
l1=l.copy()

# %%
l1

# %%
l1==l

# %%
id(l1)!=id(l)

# %%
l1.count(30)

# %%
l1.clear()
l1

# %%
del l1

# %%
l2=[]
l2

# %%
l2.append(9)
l2.append('nit')
l2.append(True)
l2.append(1+2j)
l2.append(0.5)
l2

# %%
l2[1][0]

# %%
l2.insert(14,2)
l2

# %%
l2.pop()
l2

# %%
l2.pop()

# %%
9 in l2

# %%
1000 in l2

# %%
for i in l2:
    print(i)

# %%
l2

# %%
for i in enumerate(l2):
    print(i)

# %%
print(l2)

# %%
l1=[1,2,3,4,5,6]
l1

# %%
l2.extend(l1)
l2

# %%
l1.sort(reverse=True)
l1

# %%
l3=[1,2.3,True,'nit']
l3.sort()
l3

# %%
l4=['a','z','c']
l4.sort()
l4

# %%
l4.sort(reverse=True)
l4

# %%
all(l4)

# %%
any(l4)

# %%
t=()
type(t)

# %%
s={}
s

# %%
type(s)

# %%
s1=set(s)
type(s1)

# %%
s1.add(30)
s1.add(40)
s1.add(50)
s1
type(s1)

# %%
s1.add(10)
s1
s1[:]

# %%
s2=set()
s2
type(s2)

# %%
s2.add(10)
s2.add(1.2)
s2.add(1+2j)
s2.add('nit')
s2

# %%
id(s1)==id(s2)

# %%
print(s1)
print(s2)

# %%
s3=s2.copy()
s3

# %%
s2==s3

# %%
s2.pop()

# %%
s2.remove(1+2j)
s2

# %%
s3.remove(1000)
s3

# %%
s3.discard(1000)
s3

# %%
s3.discard(True)

# %%
print(s1)
print(s2)
print(s3)

# %%
for i in enumerate(s2):
    print(i)

# %%
help()

# %%
import numpy as np

# %%
np.__version__

# %%
import sys
sys.version

# %%
my_list=[0,1,2,3,4,5]
my_list
type(my_list)

# %%
arr=np.array(my_list)
arr

# %%
type(arr)

# %%
np.arange(10,50,5)

# %%
np.arange(10,30,40,3)

# %%
n=np.arange(-20,8)
n
print(n)

# %%
np.zeros(3,dtype=int)

# %%
np.zeros(3)

# %%
z=np.zeros(5)
z

# %%
y=np.zeros((5,5))
y

# %%
y.shape

# %%
abc=np.ones((10,10),dtype=int)
abc

# %%
from numpy.random import randint

randint(-20, 10,5)

# %%
arr=np.arr(1,2,3,4,5,6)
arr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 arr=np.arr(1,2,3,4,5,6)
#       2 arr
#
# NameError: name 'np' is not defined
